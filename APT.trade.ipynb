# %%
import pandas as pd
df_apttrade = pd.read_csv("../1.Main data/trade_apt_api.csv")
df = pd.DataFrame

# %%
df_apttrade.head()
# Out:
#      거래금액  건축년도     년   지역명                    아파트  월   일    전용면적    지번  \
# 0   80000  2002  2021   신교동               신현(101동)  8  16   84.82  6-13
# 1  209000  2008  2021   사직동       광화문풍림스페이스본(106동)  8   5  163.33   9-1
# 2  160000  2008  2021   사직동  광화문풍림스페이스본(101동~105동)  8  10  158.99     9
# 3   96000  2008  2021   견지동                대성스카이렉스  8   4  116.03   110
# 4   32000  2003  2021   익선동                 현대뜨레비앙  8  14   48.54    55
#
#     지역코드   층  해제사유발생일     해제여부
# 0  11110   1  [Table]  [Table]
# 1  11110  13  [Table]  [Table]
# 2  11110   4  [Table]  [Table]
# 3  11110   5  [Table]  [Table]
# 4  11110   7  [Table]  [Table]

# %%
df_apttrade.isnull()
# Out:
#       거래금액   건축년도      년    지역명    아파트      월      일   전용면적     지번   지역코드  \
# 0    False  False  False  False  False  False  False  False  False  False
# 1    False  False  False  False  False  False  False  False  False  False
# 2    False  False  False  False  False  False  False  False  False  False
# 3    False  False  False  False  False  False  False  False  False  False
# 4    False  False  False  False  False  False  False  False  False  False
# ..     ...    ...    ...    ...    ...    ...    ...    ...    ...    ...
# 313  False  False  False  False  False  False  False  False  False  False
# 314  False  False  False  False  False  False  False  False  False  False
# 315  False  False  False  False  False  False  False  False  False  False
# 316  False  False  False  False  False  False  False  False  False  False
# 317  False  False  False  False  False  False  False  False  False  False
#
#          층  해제사유발생일   해제여부
# 0    False    False  False
# ...

# %%
df_apttrade.sum()
# Out:
# 거래금액                                                31127900
# 건축년도                                                  637260
# 년                                                     642678
# 지역명         신교동 사직동 사직동 견지동 익선동 연건동 연건동 명륜2가 창신동 창신동 숭인동 ...
# 아파트        신현(101동)광화문풍림스페이스본(106동)광화문풍림스페이스본(101동~105동)대...
# 월                                                       1296
# 일                                                       5030
# 전용면적                                              25914.5474
# 지번         6-139-1911055195-10195-10423-7670376296-19202-...
# 지역코드                                                 3532980
# 층                                                       2407
# 해제사유발생일    [Table][Table][Table][Table][Table][Table][Tab...
# 해제여부       [Table][Table][Table][Table][Table][Table][Tab...
# dtype: object

# %%
df_apttrade.tail(6)
# Out:
#        거래금액  건축년도     년   지역명       아파트  월   일      전용면적  지번   지역코드   층  \
# 312  138000  2019  2021   무악동  경희궁 롯데캐슬  1  15   59.6737  89  11110   4
# 313   86470  2000  2021   무악동        현대  1  17   60.0000  82  11110   1
# 314   86500  2000  2021   무악동        현대  1  17   60.0000  82  11110   1
# 315  135000  2019  2021   무악동  경희궁 롯데캐슬  1  22   59.6737  89  11110  13
# 316  120000  2008  2021   무악동   인왕산아이파크  1  27  114.9310  60  11110   9
# 317  109990  2000  2021   무악동        현대  1  30   84.9200  82  11110   9
#
#      해제사유발생일     해제여부
# 312  [Table]  [Table]
# 313  [Table]  [Table]
# 314  [Table]  [Table]
# 315  [Table]  [Table]
# 316  [Table]  [Table]
# 317  [Table]  [Table]

# %%
df_apttrade.head(7)
# Out:
#      거래금액  건축년도     년   지역명                    아파트  월   일    전용면적      지번  \
# 0   80000  2002  2021   신교동               신현(101동)  8  16   84.82    6-13
# 1  209000  2008  2021   사직동       광화문풍림스페이스본(106동)  8   5  163.33     9-1
# 2  160000  2008  2021   사직동  광화문풍림스페이스본(101동~105동)  8  10  158.99       9
# 3   96000  2008  2021   견지동                대성스카이렉스  8   4  116.03     110
# 4   32000  2003  2021   익선동                 현대뜨레비앙  8  14   48.54      55
# 5   19700  2014  2021   연건동                  이화에수풀  8   2   16.98  195-10
# 6   20000  2014  2021   연건동                  이화에수풀  8  29   16.98  195-10
#
#     지역코드   층  해제사유발생일     해제여부
# 0  11110   1  [Table]  [Table]
# 1  11110  13  [Table]  [Table]
# 2  11110   4  [Table]  [Table]
# 3  11110   5  [Table]  [Table]
# 4  11110   7  [Table]  [Table]
# 5  11110   4  [Table]  [Table]
# 6  11110  12  [Table]  [Table]

# %%
df_apttrade.sum()
# Out:
# 거래금액                                                31127900
# 건축년도                                                  637260
# 년                                                     642678
# 지역명         신교동 사직동 사직동 견지동 익선동 연건동 연건동 명륜2가 창신동 창신동 숭인동 ...
# 아파트        신현(101동)광화문풍림스페이스본(106동)광화문풍림스페이스본(101동~105동)대...
# 월                                                       1296
# 일                                                       5030
# 전용면적                                              25914.5474
# 지번         6-139-1911055195-10195-10423-7670376296-19202-...
# 지역코드                                                 3532980
# 층                                                       2407
# 해제사유발생일    [Table][Table][Table][Table][Table][Table][Tab...
# 해제여부       [Table][Table][Table][Table][Table][Table][Tab...
# dtype: object

# %%
df.loc[1:5][1:3]
# Out:
# -------------------------------------------------------------------
# TypeError                         Traceback (most recent call last)
# Cell In[24], line 1
# ----> 1 df.loc[1:5][1:3]
#
# TypeError: 'property' object is not subscriptable
